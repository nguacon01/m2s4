# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
df = pd.read_csv("output/output_predictions_epoche_9.csv")
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-c127caeb6ccf> in <module>
# ----> 1 df = pd.read_csv("output/output_predictions_epoche_9.csv")
#       2 print(df)
#
# ~\Anaconda3\envs\nguacon01\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\envs\nguacon01\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\envs\nguacon01\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\envs\nguacon01\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\envs\nguacon01\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'output/output_predictions_epoche_9.csv' does not exist: b'output/output_predictions_epoche_9.csv'

# %%
confusion_matrix = pd.crosstab(df['label'],df['predictions'], rownames = ['Actual'], colnames=['Predict'])
sns.heatmap(confusion_matrix,annot=True)

# %%
#%%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from helper_functions import train_test_split

plt.figure(figsize=(10,10))

df = pd.read_csv("output/FY/dataframe.csv")
df.shape
train_df, test_df = train_test_split(df, 0.2)
data = train_df['label'].value_counts()
print(data)
data.plot(kind="bar")
# plt.rcParams.update({'font.size': 14})
plt.ylabel("numbers of gene", size=14)
plt.show()
# ax = sns.barplot(df['label'].value_counts())



# ax = sns.scatterplot(x="insertion_index", y="NI_index", hue="label", data=df)

# sns.heatmap([train_df.hits_count,train_df.read_count],annot=True,fmt="d")

# %%
# sns.scatterplot(y='hits_count_pro', x='hits_count', data = df, hue='label')

# %%




# %%
# Out:
# non_ess    1427
# ess         562
# Name: label, dtype: int64

# %%
plt.figure(figsize=(10,10))
df = pd.read_csv("output/output_predictions_epoche_4.csv")
confusion_matrix = pd.crosstab(df['label'],df['predictions'], rownames = ['Actual'], colnames=['Predict'])
sns.heatmap(confusion_matrix,annot=True,annot_kws={"size": 22,"color":"red"})

# plt.rcParams.update({'font.size': 14})
plt.show()
