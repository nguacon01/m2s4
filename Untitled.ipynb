# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
df = pd.read_csv("output/output_predictions_epoche_9.csv")
print(df)
# Out:
#      hits_count  read_count  hits_count_pro  reads_count_pro  orf_len  \
# 0            64         953               8              145     2090
# 1             0           0               2                6      332
# 2            11         111               1               12      532
# 3             1           3               3               43      626
# 4            38         374               3               13     2201
# ..          ...         ...             ...              ...      ...
# 288          28         181               7              172     1088
# 289           4          12               0                0     1832
# 290          48         513               1                2     3389
# 291           0           0               0                0      917
# 292          39         409               0                0     3326
#
#      insertion_index  nonCoding_windows  NI_index  HFI_normalized      orf  \
# 0           0.030622           0.025523  1.199795        0.112919  YIL108W
# 1           0.000000           0.032543  0.000000        1.000000  YDR382W
# 2           0.020677           0.025300  0.817256        0.325188  YDR397C
# 3           0.001597           0.020855  0.076599        0.974441  YDR013W
# 4           0.017265           0.025929  0.665849        0.207179  YJL168C
# ..               ...                ...       ...             ...      ...
# 288         0.025735           0.012110  2.125215        0.145221  YGR028W
# 289         0.002183           0.019469  0.112146        0.415939  YDL153C
# 290         0.014163           0.030752  0.460569        0.100915  YBR245C
# 291         0.000000           0.037118  0.000000        1.000000  YGR277C
# 292         0.011726           0.021073  0.556436        0.128683  YBR059C
#
#        label predictions
# 0    non_ess     non_ess
# 1    non_ess         ess
# 2        ess     non_ess
# 3        ess     non_ess
# 4    non_ess     non_ess
# ..       ...         ...
# 288  non_ess     non_ess
# 289      ess         ess
# 290  non_ess     non_ess
# 291      ess         ess
# 292  non_ess     non_ess
#
# [293 rows x 12 columns]

# %%
confusion_matrix = pd.crosstab(df['label'],df['predictions'], rownames = ['Actual'], colnames=['Predict'])
sns.heatmap(confusion_matrix,annot=True)
