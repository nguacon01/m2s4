# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
df = pd.read_csv("/home/mddo/stage/M2S4/output/FY/diploid_/diploid_0/df/normal_KNN_removed_removed.csv")

print(df)
# Out:
# hits_count  reads_count  hits_count_pro   orf_len  insertion_index  \
# 0       0.054913     0.039589        0.162162  0.017981         0.060510
# 1       0.031792     0.040972        0.270270  0.013895         0.043307
# 2       0.002890     0.000173        0.000000  0.021251         0.002762
# 3       0.014451     0.040280        0.081081  0.012056         0.022026
# 4       0.054913     0.017893        0.081081  0.117899         0.010668
# ...          ...          ...             ...       ...              ...
# 5644    0.014451     0.007088        0.000000  0.023294         0.012755
# 5645    0.089595     0.025240        0.000000  0.079281         0.025535
# 5646    0.000000     0.000000        0.000000  0.017573         0.000000
# 5647    0.000000     0.000000        0.000000  0.207601         0.000000
# 5648    0.000000     0.000000        0.000000  0.029424         0.000000
#
#             NI       HFI        orf    label
# 0     2.806597  0.168790    YAL069W  non_ess
# 1     2.021966  0.574803  YAL068W-A  non_ess
# 2     0.133049  0.549724    YAL068C  non_ess
# 3     1.095846  0.845815  YAL067W-A  non_ess
# 4     0.646895  0.253790    YAL067C  non_ess
# ...        ...       ...        ...      ...
# 5644  0.485241  0.387755    YPR200C  non_ess
# 5645  0.980966  0.151565    YPR201W  non_ess
# 5646  0.000000  1.000000    YPR203W  non_ess
# 5647  0.000000  1.000000    YPR204W  non_ess
# 5648  0.041741  1.000000  YPR204C-A  non_ess
#
# [5649 rows x 9 columns]

# %%
sns.boxplot(x = "label", y="hits_count", data=df)
