# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
##load dataset
df = pd.read_csv("/home/mddo/stage/M2S4/output/FY/diploid_/diploid_0/df/normal.csv",header = None)
print(df)
dataset = df.values
print(dataset)
# Out:
# 0         1         2         3         4         5         6  \
# 0     0.054913  0.039589  0.162162  0.017981  0.060510  2.806597  0.168790
# 1     0.031792  0.040972  0.270270  0.013895  0.043307  2.021966  0.574803
# 2     0.002890  0.000173  0.000000  0.021251  0.002762  0.133049  0.549724
# 3     0.014451  0.040280  0.081081  0.012056  0.022026  1.095846  0.845815
# 4     0.054913  0.017893  0.081081  0.117899  0.010668  0.646895  0.253790
# ...        ...       ...       ...       ...       ...       ...       ...
# 6347  0.014451  0.007088  0.000000  0.023294  0.012755  0.485241  0.387755
# 6348  0.089595  0.025240  0.000000  0.079281  0.025535  0.980966  0.151565
# 6349  0.008671  0.000432  0.000000  0.055442  0.003472  0.156202  0.752315
# 6350  0.000000  0.000000  0.000000  0.017573  0.000000  0.000000  1.000000
# 6351  0.000000  0.000000  0.000000  0.207601  0.000000  0.000000  1.000000
#
#               7        8
# 0       YAL069W  non_ess
# 1     YAL068W-A  non_ess
# 2       YAL068C  non_ess
# 3     YAL067W-A  non_ess
# 4       YAL067C  non_ess
# ...         ...      ...
# 6347    YPR200C  non_ess
# 6348    YPR201W  non_ess
# 6349    YPR202W  non_ess
# 6350    YPR203W  non_ess
# 6351    YPR204W  non_ess
#
# [6352 rows x 9 columns]
# [[0.05491329479768786 0.03958855562278503 0.16216216216216214 ...
#   0.16878980891719744 'YAL069W' 'non_ess']
#  [0.031791907514450865 0.04097156193275132 0.2702702702702703 ...
#   0.5748031496062992 'YAL068W-A' 'non_ess']
#  [0.0028901734104046237 0.00017287578874578615 0.0 ... 0.5497237569060773
#   'YAL068C' 'non_ess']
#  ...
#  [0.008670520231213872 0.0004321894718644654 0.0 ... 0.7523148148148148
#   'YPR202W' 'non_ess']
#  [0.0 0.0 0.0 ... 1.0 'YPR203W' 'non_ess']
#  [0.0 0.0 0.0 ... 1.0 'YPR204W' 'non_ess']]
